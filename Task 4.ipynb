# %% [markdown]
# ---
# # **Task 4 - Image to Pencil Sketch with Python**
# ---

# %% [markdown]
# ---
# # **Name : Harrish Ragavendar S**
# ---

# %% [markdown]
# ## **Importing the libraries**

# %%
import cv2
from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## **Loading the Image**

# %%
img = cv2.imread("image.jpg")
img = cv2.resize(img,(479,270))
i_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(i_rgb)

# %% [markdown]
# ## **Converting Image to Grayscale**

# %%
from IPython.display import display
greyimg = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
display(Image.fromarray(greyimg))
# Out:
# <PIL.Image.Image image mode=L size=479x270 at 0x7F3719B83A50>

# %% [markdown]
# ## **Converting Image to Negative**

# %%
invtimg = cv2.bitwise_not(greyimg)
display(Image.fromarray(invtimg))
# Out:
# <PIL.Image.Image image mode=L size=479x270 at 0x7F3719AC94D0>

# %% [markdown]
# ## **Smoothening the Image**

# %%
blurimg = cv2.GaussianBlur(invtimg,(5,5),0,0)
display(Image.fromarray(blurimg))
# Out:
# <PIL.Image.Image image mode=L size=479x270 at 0x7F3719AF29D0>

# %% [markdown]
# ## **Creating the Pencil Sketch**

# %%
invtblurimg = 255 - blurimg
sketch = cv2.divide(greyimg,invtblurimg,scale=250.0)
display(Image.fromarray(sketch))
# Out:
# <PIL.Image.Image image mode=L size=479x270 at 0x7F3719AF2410>

# %% [markdown]
# ## **Comparing the Original Image with Pencil Sketch**

# %%
display(Image.fromarray(i_rgb))
display(Image.fromarray(sketch))
# Out:
# <PIL.Image.Image image mode=RGB size=479x270 at 0x7F3719AE2550>
# <PIL.Image.Image image mode=L size=479x270 at 0x7F3719AE22D0>
